# %%
from models.baselines import hyperparam_search

hyperparam_search()

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import wandb
# from torch.utils.data import DataLoader, random_split
# from torchvision.datasets import DatasetFolder
# from torchvision.transforms import ToTensor
#
# # Set hyperparameters and initialize WandB
# wandb.init(project="multitask-learning", config={
#     "epochs": 50,
#     "batch_size": 32,
#     "learning_rate": 0.001,
#     "weight_decay": 0.01,
#     "dropout": 0.5
# })
#
# # Define the loss function
# criterion = nn.MSELoss()
#
# # Define the optimizer with weight decay and learning rate scheduler
# optimizer = optim.Adam(net.parameters(), lr=wandb.config.learning_rate, weight_decay=wandb.config.weight_decay)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
