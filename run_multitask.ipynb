# %%
from papyrus import data_preparation
from models.baselines import run_baseline, run_baseline_hyperparam

import wandb

import os
os.environ["WANDB_NOTEBOOK_NAME"] = "./run_multitask.ipynb"

# get today's date as yyyy/mm/dd format
from datetime import date
today = date.today()
today = today.strftime("%Y%m%d")
# Out:
# 2023.03.1
# Device: cuda

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: bolak92. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Data Preparation

# %%
# preparing the xc50 dataset - scaffold split
train_data_xc50_scaffold, val_data_xc50_scaffold, test_data_xc50_scaffold, df_xc50_scaffold = data_preparation(papyrus_path='data/', activity='xc50', organism='Homo sapiens (Human)', n_top=20, multitask=True, std_smiles=True, split_type='scaffold', output_path='data/dataset/xc50/scaffold/', verbose_files=True)

# %%
# # preparing the xc50 dataset
train_data_xc50, val_data_xc50, test_data_xc50, df_xc50 = data_preparation(papyrus_path='data/', activity='xc50', organism='Homo sapiens (Human)', n_top=20, multitask=True, std_smiles=True, split_type='random', output_path='data/dataset/xc50/random/', verbose_files=True)

# %%
# # preparing the kx dataset
train_data_kx, val_data_kx, test_data_kx, df_kx = data_preparation(papyrus_path='data/', activity='kx', organism='Homo sapiens (Human)', n_top=20, multitask=True, std_smiles=True, split_type='random', output_path='data/dataset/kx/random/', verbose_files=True)

# %%
# preparing the kx dataset
train_data_kx_scaffold, val_data_kx_scaffold, test_data_kx_scaffold, df_kx_scaffold = data_preparation(papyrus_path='data/', activity='kx', organism='Homo sapiens (Human)', n_top=20, multitask=True, std_smiles=True, split_type='scaffold', output_path='data/dataset/kx/scaffold/', verbose_files=True)

# %% [markdown]
# ## Baseline Model

# %%
# running 10 epochs for multitask debugging
test_loss, test_rmse, test_r2, test_evs = run_baseline(wandb_project_name=f"{today}-baseline")
# Out:
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>logs/wandb/run-20230605_095509-es2rcpw1</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/20230605-baseline/runs/es2rcpw1' target="_blank">young-blaze-8</a></strong> to <a href='https://wandb.ai/bolak92/20230605-baseline' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bolak92/20230605-baseline' target="_blank">https://wandb.ai/bolak92/20230605-baseline</a>
#  View run at <a href='https://wandb.ai/bolak92/20230605-baseline/runs/es2rcpw1' target="_blank">https://wandb.ai/bolak92/20230605-baseline/runs/es2rcpw1</a>
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:41<00:00,  4.18s/it]
# ============ Diagnostic Run torch.onnx.export version 2.0.0.post200 ============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.578 MB of 2.578 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_evs</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_r2</td><td>▁</td></tr><tr><td>test_rmse</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▁</td></tr><tr><td>val_evs</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>val_loss</td><td>█▆▅▃▂▂▂▁▁▁</td></tr><tr><td>val_r2</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>val_rmse</td><td>█▆▅▃▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>test_evs</td><td>0.98596</td></tr><tr><td>test_loss</td><td>4.07612</td></tr><tr><td>test_r2</td><td>0.98589</td></tr><tr><td>test_rmse</td><td>0.18004</td></tr><tr><td>train_loss</td><td>3.91452</td></tr><tr><td>val_evs</td><td>0.98585</td></tr><tr><td>val_loss</td><td>4.09896</td></tr><tr><td>val_r2</td><td>0.98579</td></tr><tr><td>val_rmse</td><td>0.17888</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">young-blaze-8</strong> at: <a href='https://wandb.ai/bolak92/20230605-baseline/runs/es2rcpw1' target="_blank">https://wandb.ai/bolak92/20230605-baseline/runs/es2rcpw1</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>logs/wandb/run-20230605_095509-es2rcpw1/logs</code>

# %%
# running sweep for multitask
# test_loss = run_pipeline(sweep=True)
run_baseline_hyperparam(wandb_project_name=f"{today}-baseline-hyperparam", sweep_count=100)
# Out:
# Create sweep with ID: vcs6ka47
# Sweep URL: https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47
# wandb: Agent Starting Run: c1dy3x8z with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.2
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 2048
# wandb: 	hidden_dim_2: 256
# wandb: 	hidden_dim_3: 128
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.01
# wandb: 	loss: huber
# wandb: 	lr_factor: 0.5
# wandb: 	lr_patience: 20
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: sgd
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.001
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>logs/wandb/run-20230605_021746-c1dy3x8z</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/c1dy3x8z' target="_blank">olive-sweep-1</a></strong> to <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View project at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View run at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/c1dy3x8z' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/c1dy3x8z</a>
#   7%|██████████▏                                                                                                                                           | 203/3000 [03:47<49:23,  1.06s/it]
# Epoch 00203: reducing learning rate of group 0 to 5.0000e-03.
#   8%|████████████▏                                                                                                                                         | 243/3000 [04:30<51:22,  1.12s/it]
# Epoch 00243: reducing learning rate of group 0 to 2.5000e-03.
#   9%|█████████████▏                                                                                                                                        | 264/3000 [04:55<52:35,  1.15s/it]
# Epoch 00264: reducing learning rate of group 0 to 1.2500e-03.
#  10%|██████████████▎                                                                                                                                       | 285/3000 [05:19<51:28,  1.14s/it]
# Epoch 00285: reducing learning rate of group 0 to 6.2500e-04.
#  10%|███████████████▊                                                                                                                                      | 315/3000 [05:52<50:09,  1.12s/it]
# Epoch 00315: reducing learning rate of group 0 to 3.1250e-04.
#  11%|████████████████▊                                                                                                                                     | 336/3000 [06:15<45:03,  1.01s/it]
# Epoch 00336: reducing learning rate of group 0 to 1.5625e-04.
#  12%|█████████████████▊                                                                                                                                    | 357/3000 [06:40<54:25,  1.24s/it]
# Epoch 00357: reducing learning rate of group 0 to 7.8125e-05.
#  13%|██████████████████▉                                                                                                                                   | 378/3000 [07:03<48:07,  1.10s/it]
# Epoch 00378: reducing learning rate of group 0 to 3.9063e-05.
#  13%|███████████████████▋                                                                                                                                  | 394/3000 [07:23<48:51,  1.13s/it]
# ============ Diagnostic Run torch.onnx.export version 2.0.0.post200 ============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_evs</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_r2</td><td>▁</td></tr><tr><td>test_rmse</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_evs</td><td>▁▆▇▇▇▇▇▇▇█▇▇█▇██████████████████████████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_r2</td><td>▁▆▇▇▇▇▇▇▇█▇██▇██████████████████████████</td></tr><tr><td>val_rmse</td><td>█▃▃▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>394</td></tr><tr><td>test_evs</td><td>0.99013</td></tr><tr><td>test_loss</td><td>3.49245</td></tr><tr><td>test_r2</td><td>0.99013</td></tr><tr><td>test_rmse</td><td>0.1504</td></tr><tr><td>train_loss</td><td>0.22715</td></tr><tr><td>val_evs</td><td>0.99011</td></tr><tr><td>val_loss</td><td>3.49646</td></tr><tr><td>val_r2</td><td>0.99011</td></tr><tr><td>val_rmse</td><td>0.14846</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">olive-sweep-1</strong> at: <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/c1dy3x8z' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/c1dy3x8z</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>logs/wandb/run-20230605_021746-c1dy3x8z/logs</code>
# wandb: Agent Starting Run: ftc7ag3r with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.2
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 512
# wandb: 	hidden_dim_2: 512
# wandb: 	hidden_dim_3: 256
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.001
# wandb: 	loss: huber
# wandb: 	lr_factor: 0.5
# wandb: 	lr_patience: 20
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: sgd
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.001
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>logs/wandb/run-20230605_022542-ftc7ag3r</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/ftc7ag3r' target="_blank">elated-sweep-2</a></strong> to <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View project at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View run at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/ftc7ag3r' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/ftc7ag3r</a>
#   5%|███████▉                                                                                                                                            | 162/3000 [04:54<1:22:42,  1.75s/it]
# Epoch 00162: reducing learning rate of group 0 to 5.0000e-04.
#   7%|██████████▎                                                                                                                                         | 208/3000 [06:15<1:21:50,  1.76s/it]
# Epoch 00208: reducing learning rate of group 0 to 2.5000e-04.
#   8%|███████████▎                                                                                                                                        | 229/3000 [06:55<1:32:57,  2.01s/it]
# Epoch 00229: reducing learning rate of group 0 to 1.2500e-04.
#   8%|████████████▎                                                                                                                                       | 250/3000 [07:33<1:21:49,  1.79s/it]
# Epoch 00250: reducing learning rate of group 0 to 6.2500e-05.
#   9%|█████████████▎                                                                                                                                      | 271/3000 [08:10<1:22:05,  1.80s/it]
# Epoch 00271: reducing learning rate of group 0 to 3.1250e-05.
#  10%|██████████████▏                                                                                                                                     | 287/3000 [08:41<1:22:05,  1.82s/it]
# ============ Diagnostic Run torch.onnx.export version 2.0.0.post200 ============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_evs</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_r2</td><td>▁</td></tr><tr><td>test_rmse</td><td>▁</td></tr><tr><td>train_loss</td><td>█▆▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_evs</td><td>▁▄▆▇▇▇▇▇████████████████████████████████</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_r2</td><td>▁▄▆▇▇▇▇█████████████████████████████████</td></tr><tr><td>val_rmse</td><td>█▅▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>287</td></tr><tr><td>test_evs</td><td>0.98797</td></tr><tr><td>test_loss</td><td>4.07457</td></tr><tr><td>test_r2</td><td>0.98797</td></tr><tr><td>test_rmse</td><td>0.16682</td></tr><tr><td>train_loss</td><td>0.64479</td></tr><tr><td>val_evs</td><td>0.98809</td></tr><tr><td>val_loss</td><td>4.02473</td></tr><tr><td>val_r2</td><td>0.98809</td></tr><tr><td>val_rmse</td><td>0.1639</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-2</strong> at: <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/ftc7ag3r' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/ftc7ag3r</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>logs/wandb/run-20230605_022542-ftc7ag3r/logs</code>
# wandb: Agent Starting Run: g0lf3vx3 with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.2
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 512
# wandb: 	hidden_dim_2: 512
# wandb: 	hidden_dim_3: 128
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.001
# wandb: 	loss: mse
# wandb: 	lr_factor: 0.5
# wandb: 	lr_patience: 20
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: adamw
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.001
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>logs/wandb/run-20230605_023450-g0lf3vx3</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/g0lf3vx3' target="_blank">splendid-sweep-3</a></strong> to <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View project at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/sweeps/vcs6ka47</a>
#  View run at <a href='https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/g0lf3vx3' target="_blank">https://wandb.ai/bolak92/20230605-baseline-hyperparam/runs/g0lf3vx3</a>
#   1%|█▉                                                                                                                                                   | 39/3000 [01:20<1:44:52,  2.13s/it]

# %%
#
