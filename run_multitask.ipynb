# %%
from papyrus import data_preparation
from models.baselines import run_pipeline

import wandb
# Out:
# 2023.03.1
# Device: cuda

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: bolak92. Use `wandb login --relogin` to force relogin
# True

# %%
# preparing the xc50 dataset
train_data_xc50, val_data_xc50, test_data_xc50, df_xc50 = data_preparation(papyrus_path='data/', activity='xc50', n_top=20, multitask=True, std_smiles=True, output_path='data/dataset/xc50/', verbose_files=True)

# preparing the kx dataset
train_data_kx, val_data_kx, test_data_kx, df_kx = data_preparation(papyrus_path='data/', activity='kx', n_top=20, multitask=True, std_smiles=True, output_path='data/dataset/kx/', verbose_files=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 # preparing the xc50 dataset
# ----> 2 train_data_xc50, val_data_xc50, test_data_xc50, df_xc50 = data_preparation(papyrus_path='data/', activity='xc50', n_top=20, multitask=True, std_smiles=True, output_path='data/dataset/xc50/', verbose_files=True)
#       4 # preparing the kx dataset
#       5 train_data_kx, val_data_kx, test_data_kx, df_kx = data_preparation(papyrus_path='data/', activity='kx', n_top=20, multitask=True, std_smiles=True, output_path='data/dataset/kx/', verbose_files=True)
#
# File ~\OneDrive - JNJ\Documents\PhD\JKU\master_thesis\Practical in AI\uncertainty-estimation-dd\papyrus.py:332, in data_preparation(papyrus_path, activity, n_top, multitask, std_smiles, output_path, verbose_files)
#     329 activity = activity.lower()
#     331 # Read the data
# --> 332 papyrus_ = Papyrus(
#     333     path=papyrus_path,
#     334     chunksize=1000000,
#     335     accession=None,
#     336     activity_type=act_dict[activity],
#     337     protein_class=None,
#     338     std_smiles=std_smiles,
#     339     verbose_files=verbose_files,
#     340 )
#     341 df = papyrus_()
#     342 # step 1: group the dataframe by protein target
#     343 # print(df_xc50.shape)
#
# File ~\OneDrive - JNJ\Documents\PhD\JKU\master_thesis\Practical in AI\uncertainty-estimation-dd\papyrus.py:146, in Papyrus.__init__(self, path, chunksize, accession, activity_type, protein_class, std_smiles, verbose_files)
#     144 else:
#     145     self.df_filtered = None
# --> 146     self.papyrus_data, self.papyrus_protein_data = self.reader()
#
# File ~\OneDrive - JNJ\Documents\PhD\JKU\master_thesis\Practical in AI\uncertainty-estimation-dd\papyrus.py:172, in Papyrus.reader(self)
#     171 def reader(self):
# --> 172     self._download()
#     173     papyrus_data = read_papyrus(
#     174         is3d=False,
#     175         version="latest",
#    (...)
#     178         source_path=self.papyrus_path,
#     179     )
#     180     papyrus_protein_data = read_protein_set(source_path=self.papyrus_path, version="latest")
#
# File ~\OneDrive - JNJ\Documents\PhD\JKU\master_thesis\Practical in AI\uncertainty-estimation-dd\papyrus.py:157, in Papyrus._download(self)
#     154     os.makedirs(self.papyrus_path, exist_ok=True)
#     156 self.log.info("Downloading Papyrus data ...")
# --> 157 download_papyrus(
#     158     outdir=self.papyrus_path,
#     159     version="latest",
#     160     nostereo=True,
#     161     stereo=False,
#     162     only_pp=False,
#     163     structures=False,
#     164     descriptors="all",
#     165     progress=True,
#     166     disk_margin=0.01,
#     167 )
#     169 return None
#
# File C:\ProgramData\anaconda3\envs\uqdd-env\lib\site-packages\papyrus_scripts\download.py:44, in download_papyrus(outdir, version, nostereo, stereo, only_pp, structures, descriptors, progress, disk_margin)
#      42 RETRIES = 3
#      43 # Obtain links to files
# ---> 44 files = get_papyrus_links()
#      45 available_versions = list(files.keys())
#      46 if isinstance(version, list):
#
# File C:\ProgramData\anaconda3\envs\uqdd-env\lib\site-packages\papyrus_scripts\utils\IO.py:272, in get_papyrus_links(offline)
#     270 try:
#     271     res = session.get(url, verify=True)
# --> 272     with open(local_file, 'w') as oh:
#     273         oh.write(res.text)
#     274 except requests.exceptions.ConnectionError as e:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\ProgramData\\anaconda3\\envs\\uqdd-env\\lib\\site-packages\\papyrus_scripts\\utils\\links.json'

# %%
# running 10 epochs for multitask debugging
test_loss = run_pipeline(sweep=False)

# %%
# running sweep for multitask
test_loss = run_pipeline(sweep=True)
# Out:
# Create sweep with ID: gwijfbxw
# Sweep URL: https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw
# wandb: Agent Starting Run: 9bqprm76 with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 2048
# wandb: 	hidden_dim_2: 512
# wandb: 	hidden_dim_3: 128
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.001
# wandb: 	loss: huber
# wandb: 	lr_factor: 0.1
# wandb: 	lr_patience: 10
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: adamw
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/mnt/code/logs/wandb/run-20230531_161037-9bqprm76</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/9bqprm76' target="_blank">magic-sweep-1</a></strong> to <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View project at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View run at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/9bqprm76' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/9bqprm76</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.019 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.783538…
#  View run <strong style="color:#cdcd00">magic-sweep-1</strong> at: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/9bqprm76' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/9bqprm76</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./logs/wandb/run-20230531_161037-9bqprm76/logs</code>
# Run 9bqprm76 errored: PermissionError(13, 'Permission denied')
# wandb: ERROR Run 9bqprm76 errored: PermissionError(13, 'Permission denied')
# wandb: Agent Starting Run: zeznwfmu with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 512
# wandb: 	hidden_dim_2: 512
# wandb: 	hidden_dim_3: 256
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.01
# wandb: 	loss: huber
# wandb: 	lr_factor: 0.1
# wandb: 	lr_patience: 10
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: adamw
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/mnt/code/logs/wandb/run-20230531_161048-zeznwfmu</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/zeznwfmu' target="_blank">hearty-sweep-2</a></strong> to <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View project at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View run at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/zeznwfmu' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/zeznwfmu</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.019 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.783598…
#  View run <strong style="color:#cdcd00">hearty-sweep-2</strong> at: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/zeznwfmu' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/zeznwfmu</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./logs/wandb/run-20230531_161048-zeznwfmu/logs</code>
# Run zeznwfmu errored: PermissionError(13, 'Permission denied')
# wandb: ERROR Run zeznwfmu errored: PermissionError(13, 'Permission denied')
# wandb: Agent Starting Run: hav2tt34 with config:
# wandb: 	activity: xc50
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.2
# wandb: 	early_stop: 100
# wandb: 	ensemble_size: 100
# wandb: 	hidden_dim_1: 512
# wandb: 	hidden_dim_2: 256
# wandb: 	hidden_dim_3: 256
# wandb: 	input_dim: 2048
# wandb: 	learning_rate: 0.01
# wandb: 	loss: huber
# wandb: 	lr_factor: 0.1
# wandb: 	lr_patience: 10
# wandb: 	num_epochs: 3000
# wandb: 	num_tasks: 20
# wandb: 	optimizer: sgd
# wandb: 	output_dim: 20
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/mnt/code/logs/wandb/run-20230531_161058-hav2tt34</code>
# Syncing run <strong><a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/hav2tt34' target="_blank">firm-sweep-3</a></strong> to <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View project at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam</a>
#  View sweep at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/sweeps/gwijfbxw</a>
#  View run at <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/hav2tt34' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/hav2tt34</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.019 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.783730…
#  View run <strong style="color:#cdcd00">firm-sweep-3</strong> at: <a href='https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/hav2tt34' target="_blank">https://wandb.ai/bolak92/2023-05-31-mtl-hyperparam/runs/hav2tt34</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./logs/wandb/run-20230531_161058-hav2tt34/logs</code>
# Run hav2tt34 errored: PermissionError(13, 'Permission denied')
# wandb: ERROR Run hav2tt34 errored: PermissionError(13, 'Permission denied')
# Detected 3 failed runs in the first 60 seconds, killing sweep.
# wandb: ERROR Detected 3 failed runs in the first 60 seconds, killing sweep.
# wandb: To disable this check set WANDB_AGENT_DISABLE_FLAPPING=true

# %%
#
